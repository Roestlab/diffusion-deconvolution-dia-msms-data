# %% [markdown]
# # Feature Extraction and Visualization with MassDASH
#
# This notebook demonstrates how to extract features from raw DIA data using MassDASH. We will:
# - Measure the runtime and memory usage for extraction.
# - Display example raw data (FeatureMap DataFrame) for a few precursors.
# - Visualize the corresponding feature mask (MS1 and MS2) for selected precursors.
# - Evaluate whether these features would serve as useful conditioning signals.
#
# ---

# %%
# !pip install massdash
# Out:
# Collecting massdash
#   Downloading massdash-0.1.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: bokeh>3.0 in /usr/local/lib/python3.11/dist-packages (from massdash) (3.6.3)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from massdash) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from massdash) (1.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from massdash) (3.10.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from massdash) (2.0.2)
# Requirement already satisfied: pandas>=0.17 in /usr/local/lib/python3.11/dist-packages (from massdash) (2.2.2)
# Requirement already satisfied: plotly==5.24.1 in /usr/local/lib/python3.11/dist-packages (from massdash) (5.24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from massdash) (5.9.5)
# Collecting pyopenms>=3.2.0 (from massdash)
#   Downloading pyopenms-3.3.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from massdash) (1.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from massdash) (4.67.1)
# Collecting upsetplot (from massdash)
#   Downloading UpSetPlot-0.9.0.tar.gz (23 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from massdash) (2.32.3)
# Collecting pyopenms_viz (from massdash)
#   Downloading pyopenms_viz-1.0.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly==5.24.1->massdash) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly==5.24.1->massdash) (24.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from bokeh>3.0->massdash) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.11/dist-packages (from bokeh>3.0->massdash) (1.3.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from bokeh>3.0->massdash) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.11/dist-packages (from bokeh>3.0->massdash) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.11/dist-packages (from bokeh>3.0->massdash) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.11/dist-packages (from bokeh>3.0->massdash) (2025.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.17->massdash) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.17->massdash) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.17->massdash) (2025.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->massdash) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->massdash) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->massdash) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->massdash) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->massdash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->massdash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->massdash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->massdash) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=2.9->bokeh>3.0->massdash) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.17->massdash) (1.17.0)
# Downloading massdash-0.1.0-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 31.7 MB/s eta 0:00:00
# Downloading pyopenms-3.3.0-cp311-cp311-manylinux_2_28_x86_64.whl (57.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 MB 9.6 MB/s eta 0:00:00
# Downloading pyopenms_viz-1.0.0-py3-none-any.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.1/153.1 kB 6.0 MB/s eta 0:00:00
# Building wheels for collected packages: upsetplot
#   Building wheel for upsetplot (pyproject.toml) ... done
#   Created wheel for upsetplot: filename=upsetplot-0.9.0-py3-none-any.whl size=24864 sha256=cc8d27cde409baa031e1ff4784358786e9874981b0fd958d98693f4560bdba48
#   Stored in directory: /root/.cache/pip/wheels/7b/ce/88/1d0bce5b2680165c29c3e68416325e79674d5a9f422d037996
# Successfully built upsetplot
# Installing collected packages: upsetplot, pyopenms_viz, pyopenms, massdash
# Successfully installed massdash-0.1.0 pyopenms-3.3.0 pyopenms_viz-1.0.0 upsetplot-0.9.0

# %%
# Cell 1: Convert .parquet files into .tsv for massdash input
import pandas as pd

# ----- Convert report.parquet to TSV -----
report_df = pd.read_parquet("report.parquet")
report_df.to_csv("report.tsv", sep="\t", index=False)
print("Converted report.parquet to report.tsv")

# ----- Convert gen_lib.parquet to TSV -----
gen_lib_df = pd.read_parquet("gen_lib.parquet")
gen_lib_df.to_csv("gen_lib.tsv", sep="\t", index=False)
print("Converted gen_lib.parquet to gen_lib.tsv")

# ----- Modify gen_lib.tsv for MassDASH Input -----
# Read the TSV file
df_gen_lib = pd.read_csv("gen_lib.tsv", sep="\t")

# Rename columns as required by MassDASH
df_gen_lib = df_gen_lib.rename(columns={
    'Precursor.Charge': 'PrecursorCharge',
    'Protein.Ids': 'ProteinId',
    'Stripped.Sequence': 'PeptideSequence',
    'Precursor.Mz': 'PrecursorMz',
    'Modified.Sequence': 'ModifiedPeptideSequence',
    'Relative.Intensity': 'LibraryIntensity',
    'Product.Mz': 'ProductMz',
    'Fragment.Type': 'FragmentType',
    'Fragment.Series.Number': 'FragmentSeriesNumber',
    'Fragment.Charge': 'ProductCharge'  # Assuming this maps to ProductCharge
})

# Save the modified TSV file for MassDASH
df_gen_lib.to_csv("gen_lib_modified.tsv", sep="\t", index=False)
print("Modified gen_lib.tsv and saved as gen_lib_modified.tsv")
# Out:
# Converted report.parquet to report.tsv
# Converted gen_lib.parquet to gen_lib.tsv
# Modified gen_lib.tsv and saved as gen_lib_modified.tsv

# %%
# Cell 2: Initialize Libraries, Logging, and Data Loader
import time
import numpy as np
import cudf  # GPU DataFrame library (RAPIDS)
import logging
import psutil  # For memory usage (optional)

# Suppress excessive FeatureMap warnings
logging.getLogger("FeatureMap").setLevel(logging.ERROR)

# Helper function to print memory usage
def print_memory_usage():
    process = psutil.Process()
    mem = process.memory_info().rss / 1e6  # in MB
    print(f"Current memory usage: {mem:.2f} MB")

print("Libraries loaded.")
print_memory_usage()

# Import MassDASH classes and initialize the loader with your file paths
from massdash.loaders import MzMLDataLoader
from massdash.structs.TargetedDIAConfig import TargetedDIAConfig

# Configure extraction settings
extraction_config = TargetedDIAConfig()
extraction_config.im_window = 0.2    # Ion mobility window (if applicable)
extraction_config.rt_window = 50     # RT window in minutes
extraction_config.mz_tol = 20        # m/z tolerance

# Initialize the data loader with updated file paths
loader = MzMLDataLoader(
    dataFiles="/content/drive/MyDrive/file mzML/23aug2017_hela_serum_timecourse_4mz_narrow_1.mzML",
    rsltsFile="report.tsv",
    libraryFile="gen_lib_modified.tsv"
)

print("Data loader initialized.")
print_memory_usage()
# Out:
# Libraries loaded.
# Current memory usage: 809.85 MB
# [2025-03-25 04:51:10,891] MzMLDataAccess - INFO - Opening /content/drive/MyDrive/file mzML/23aug2017_hela_serum_timecourse_4mz_narrow_1.mzML file...: Elapsed 23.996625900268555 ms
# [2025-03-25 04:51:10,893] MzMLDataAccess - INFO - There are 87362 spectra and 1 chromatograms.
# [2025-03-25 04:51:12,214] MzMLDataAccess - INFO - There are 6242 MS1 spectra and 81120 MS2 spectra.
# Data loader initialized.
# Current memory usage: 1706.16 MB

# %%
# Cell 3: Load Unique Peptide-Charge Pairs from Report
# (Assuming your report file has already been created as a Parquet file)
report_df = pd.read_parquet("report.parquet")
unique_peptides = report_df[['Modified.Sequence', 'Precursor.Charge']].drop_duplicates()
print(f"Total unique peptides: {len(unique_peptides)}")

# For demonstration, select a small subset (e.g., first 5 peptides)
subset_peptides = unique_peptides.head(5)
subset_peptides
# Out:
# Total unique peptides: 34161
#     Modified.Sequence  Precursor.Charge
# 0         AAAAAAAAAAR                 2
# 1        AAAAAAAAAVSR                 2
# 2         AAAAAAALQAK                 2
# 3          AAAAADLANR                 2
# 4  AAAAC(UniMod:4)LDK                 2

# %%
# Cell 4: Process the Subset and Measure Extraction Time and Memory
ms1_results = []
ms2_results = []

start_total = time.time()

# Process each peptide in the subset
for idx, row in subset_peptides.iterrows():
    peptide = row['Modified.Sequence']
    charge = int(row['Precursor.Charge'])
    print(f"\nProcessing peptide: {peptide} (charge {charge})")

    start_pep = time.time()
    try:
        feature_map_collection = loader.loadFeatureMaps(peptide, charge, extraction_config)
    except Exception as e:
        print(f"Error extracting {peptide}: {e}")
        continue
    elapsed_pep = time.time() - start_pep
    print(f"Extraction for {peptide} completed in {elapsed_pep:.2f} seconds")

    # Use the first available run for demonstration
    run_name = list(feature_map_collection.keys())[0]
    feature_map = feature_map_collection[run_name]
    df = feature_map.feature_df.copy()
    df['Peptide'] = peptide
    df['Charge'] = charge
    df['Run'] = run_name

    # Convert to cuDF for GPU processing
    gpu_df = cudf.DataFrame.from_pandas(df)

    # Extract MS1 data (precursor): rows where ms_level == 1 and Annotation == 'prec'
    ms1_gpu = gpu_df[(gpu_df['ms_level'] == 1) & (gpu_df['Annotation'] == 'prec')]
    ms1_gpu = ms1_gpu[['Peptide', 'Charge', 'Run', 'rt', 'precursor_mz', 'int']]
    ms1_gpu = ms1_gpu.rename(columns={'rt': 'RetentionTime',
                                      'precursor_mz': 'Precursor_mz',
                                      'int': 'Intensity'})
    ms1_results.append(ms1_gpu.to_pandas())

    # Extract MS2 data (fragment): rows where ms_level == 2, including precursor m/z
    ms2_gpu = gpu_df[gpu_df['ms_level'] == 2]
    ms2_gpu = ms2_gpu[['Peptide', 'Charge', 'Run', 'rt', 'mz', 'precursor_mz', 'int']]
    ms2_gpu = ms2_gpu.rename(columns={'rt': 'RetentionTime',
                                      'mz': 'Fragment_mz',
                                      'precursor_mz': 'Precursor_mz',
                                      'int': 'Intensity'})
    ms2_results.append(ms2_gpu.to_pandas())

    print_memory_usage()

total_time = time.time() - start_total
print(f"\nTotal extraction time for subset: {total_time:.2f} seconds")
# Out:
# Processing peptide: AAAAAAAAAAR (charge 2)
# [2025-03-25 04:51:19,097] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,101] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,104] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,107] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,109] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,111] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,113] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,115] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,116] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,118] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,120] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,121] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,122] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,124] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,126] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,127] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,129] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,131] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,132] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,134] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,135] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,137] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,138] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,140] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,142] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,143] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,144] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,146] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,147] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,149] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,151] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,152] MzMLDataAccess - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:19,154] MzMLDataAccess - WARNING - MS2 spectrum native id  had no ion mobility array
# Extraction for AAAAAAAAAAR completed in 1.62 seconds
# Current memory usage: 1822.76 MB
#
# Processing peptide: AAAAAAAAAVSR (charge 2)
# [2025-03-25 04:51:21,712] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,713] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,715] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,718] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,720] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,721] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,723] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,726] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,727] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,728] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,731] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,733] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,734] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,736] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,738] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,739] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,741] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,743] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,744] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,746] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,748] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,750] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,751] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,753] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,754] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,757] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,758] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,760] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,762] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:21,763] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# Extraction for AAAAAAAAAVSR completed in 2.02 seconds
# Current memory usage: 1908.23 MB
#
# Processing peptide: AAAAAAALQAK (charge 2)
# [2025-03-25 04:51:23,126] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,128] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,129] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,131] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,132] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,134] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,135] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,137] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,138] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,140] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,141] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,143] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,144] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,146] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,148] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,149] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,151] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,153] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,155] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,157] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,159] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,160] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,162] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,163] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,165] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,166] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,168] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,169] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,171] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,172] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,174] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,175] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,177] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,178] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,180] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,181] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,183] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,184] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,186] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,187] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,189] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,190] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,192] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,193] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,195] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,196] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,198] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,199] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,201] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,202] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,204] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,205] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,207] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,208] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:23,210] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# Extraction for AAAAAAALQAK completed in 1.43 seconds
# Current memory usage: 1908.50 MB
#
# Processing peptide: AAAAADLANR (charge 2)
# [2025-03-25 04:51:24,611] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,612] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,614] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,616] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,617] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,619] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,620] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,622] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,623] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,625] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,627] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,628] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,630] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,631] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,633] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,635] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,636] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,638] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,639] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,641] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,642] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,644] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,645] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,647] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,649] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,650] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,652] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,653] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,655] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,656] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,658] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,660] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,661] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,663] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,667] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,669] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,670] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,672] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,673] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,675] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,676] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,677] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,679] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,680] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,682] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,683] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,685] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,686] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,688] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,689] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,690] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:24,692] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# Extraction for AAAAADLANR completed in 1.46 seconds
# Current memory usage: 1909.30 MB
#
# Processing peptide: AAAAC(UniMod:4)LDK (charge 2)
# [2025-03-25 04:51:26,074] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,076] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,077] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,079] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,082] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,083] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,085] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,086] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,088] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,089] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,091] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,092] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,093] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,095] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,097] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,098] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,100] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,101] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,103] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,105] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,106] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,108] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,109] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,111] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,112] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,114] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,116] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,118] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,119] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,121] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,123] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,125] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,126] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,128] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,130] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,132] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,134] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,136] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,138] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,140] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,141] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:51:26,144] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# Extraction for AAAAC(UniMod:4)LDK completed in 1.43 seconds
# Current memory usage: 1909.30 MB
#
# Total extraction time for subset: 8.62 seconds

# %%
# Cell 5: Combine and Save Subset Results
ms1_df = pd.concat(ms1_results, ignore_index=True)
ms2_df = pd.concat(ms2_results, ignore_index=True)

ms1_df.to_csv("ms1_features_subset.csv", index=False)
ms2_df.to_csv("ms2_features_subset.csv", index=False)

print("Subset MS1 and MS2 features saved to CSV.")
# Out:
# Subset MS1 and MS2 features saved to CSV.

# %%
# Cell 6: Visualize Raw Data and Feature Masks for a Few Precursors

# Display the first few rows of the raw FeatureMap for the first peptide in the subset
first_peptide = subset_peptides.iloc[2]
peptide = first_peptide['Modified.Sequence']
charge = int(first_peptide['Precursor.Charge'])
feature_map_collection = loader.loadFeatureMaps(peptide, charge, extraction_config)
run_name = list(feature_map_collection.keys())[0]
feature_map = feature_map_collection[run_name]
raw_df = feature_map.feature_df
print("Raw FeatureMap Data (first 10 rows):")
print(raw_df.head(10))

# If supported, plot the chromatogram (MS1) for the precursor
transition_group = loader.loadTransitionGroups(peptide, charge, extraction_config)[run_name]
transition_group.plot()  # This should open an interactive plot

# Plot the aggregated MS2 spectra (if supported)
feature_map.to_spectra().plot()
# Out:
# [2025-03-25 04:56:34,863] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,867] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,869] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,872] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,875] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,876] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,879] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,881] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,884] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,886] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,888] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,891] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,893] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,896] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,898] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,901] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,903] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,906] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,907] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,909] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,911] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,912] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,917] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,918] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,920] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,922] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,925] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,926] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,928] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,932] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,933] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,935] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,936] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,942] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,943] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,947] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,948] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,950] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,951] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,956] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,957] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,959] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,960] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,965] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,967] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,968] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,970] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,972] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,973] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,977] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,979] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,981] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,984] InteractivePlotter - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,986] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:34,988] InteractivePlotter - WARNING - MS1 spectrum native id  had no ion mobility array
# Raw FeatureMap Data (first 10 rows):
#   native_id  ms_level  precursor_mz          mz          rt           int  \
# 0                   2     478.77982  285.156281  2051.29320   7488.815430
# 1                   2     478.77982  214.118713  2053.61904   4721.731934
# 2                   2     478.77982  285.156616  2053.61904   3583.452881
# 3                   2     478.77982  356.195770  2053.61904   5070.394531
# 4                   2     478.77982  214.118912  2055.96366  14279.031250
# 5                   2     478.77982  285.154907  2055.96366   3579.629150
# 6                   2     478.77982  214.118088  2058.31272  20619.978516
# 7                   2     478.77982  285.155487  2058.31272   3218.664062
# 8                   2     478.77982  356.192810  2058.31272  13879.067383
# 9                   2     478.77982  214.118576  2060.59662  67050.640625
#
#   Annotation  product_mz
# 0       b4^1   285.15573
# 1       b3^1   214.11862
# 2       b4^1   285.15573
# 3       b5^1   356.19284
# 4       b3^1   214.11862
# 5       b4^1   285.15573
# 6       b3^1   214.11862
# 7       b4^1   285.15573
# 8       b5^1   356.19284
# 9       b3^1   214.11862
# [2025-03-25 04:56:37,079] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,083] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,087] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,089] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,091] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,093] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,095] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,096] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,098] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,099] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,101] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,102] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,104] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,106] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,107] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,109] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,110] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,112] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,113] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,115] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,116] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,118] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,119] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,121] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,122] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,124] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,125] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,128] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,129] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,130] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,132] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,134] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,136] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,138] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,139] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,141] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,143] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,144] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,146] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,148] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,150] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,151] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,153] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,154] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,156] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,157] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,159] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,160] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,162] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,163] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,165] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,167] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,168] FeatureMap - WARNING - MS2 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,170] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
# [2025-03-25 04:56:37,172] FeatureMap - WARNING - MS1 spectrum native id  had no ion mobility array
#   <div id="ef491de0-3300-4fe5-ac70-ed4f3e953e3a" data-root-id="p2468" style="display: contents;"></div>
#   <div id="c6348de6-f301-4ccf-bb95-eb9a5902f59f" data-root-id="p2699" style="display: contents;"></div>

# %% [markdown]
# # Conclusions
#
# - **Performance Metrics:**
#   The extraction of a small subset (5 peptides) took approximately 8.62 seconds, and memory usage was reported above.
#
# - **Raw Data vs. Feature Mask:**
#   The raw FeatureMap DataFrame is shown, and interactive plots of the precursor chromatogram (MS1) and aggregated MS2 spectra are generated. This helps assess the quality of the extracted features as conditioning signals.
#
# - **Next Steps:**
#   Once validated on a subset, we can scale the process to the full dataset (e.g., by splitting into batches) and further optimize parameters if needed.
